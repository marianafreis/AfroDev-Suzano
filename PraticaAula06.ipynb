# %% [markdown]
# <a href="https://colab.research.google.com/github/marianafreis/AfroDev-Suzano/blob/main/Pr%C3%A1ticaAula06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lista de dicionários com o id e o nome do usuário:

# %%
 users = [
  { "id": 0, "name": "Hero" },
  { "id": 1, "name": "Dunn" },
  { "id": 2, "name": "Sue" },
  { "id": 3, "name": "Chi" },
  { "id": 4, "name": "Thor" },
  { "id": 5, "name": "Clive" },
  { "id": 6, "name": "Hicks" },
  { "id": 7, "name": "Devin" },
  { "id": 8, "name": "Kate" },
  { "id": 9, "name": "Klein" }
]

# %% [markdown]
# Lista das amizades

# %%
friendships = [(0, 1), (0, 2), (1, 2), (1, 3), (2, 3), (3, 4), 
  (4, 5), (5, 6), (5, 7), (6, 8), (7, 8), (8, 9)]

# %% [markdown]
# Criando a lista de amigos de cada usuário

# %%
for user in users:
  user["friends"] = []

# %%
users
# Out:
# [{'friends': [], 'id': 0, 'name': 'Hero'},
#  {'friends': [], 'id': 1, 'name': 'Dunn'},
#  {'friends': [], 'id': 2, 'name': 'Sue'},
#  {'friends': [], 'id': 3, 'name': 'Chi'},
#  {'friends': [], 'id': 4, 'name': 'Thor'},
#  {'friends': [], 'id': 5, 'name': 'Clive'},
#  {'friends': [], 'id': 6, 'name': 'Hicks'},
#  {'friends': [], 'id': 7, 'name': 'Devin'},
#  {'friends': [], 'id': 8, 'name': 'Kate'},
#  {'friends': [], 'id': 9, 'name': 'Klein'}]

# %% [markdown]
# Adicionando os amigos à lista de amigos de cada usuário

# %%
for i, j in friendships:
  if i == int(users[i]['id']):
    users[i]['friends'].append(users[j])
    users[j]['friends'].append(users[i])

# %%
users
# Out:
# [{'friends': [{'friends': [{...},
#      {'friends': [{...},
#        {...},
#        {'friends': [{...},
#          {...},
#          {'friends': [{...},
#            {'friends': [{...},
#              {'friends': [{...},
#                {'friends': [{...},
#                  {'friends': [{...}, {...}], 'id': 7, 'name': 'Devin'},
#                  {'friends': [{...}], 'id': 9, 'name': 'Klein'}],
#                 'id': 8,
#                 'name': 'Kate'}],
#               'id': 6,
#               'name': 'Hicks'},
#              {'friends': [{...},
#                {'friends': [{'friends': [{...}, {...}],
#                   'id': 6,
#                   'name': 'Hicks'},
#                  {...},
#                  {'friends': [{...}], 'id': 9, 'name': 'Klein'}],
#                 'id': 8,
#                 'name': 'Kate'}],
#               'id': 7,
#               'name': 'Devin'}],
#             'id': 5,
#             'name': 'Clive'}],
#           'id': 4,
# ...

# %% [markdown]
# Criando um contador para calcular a média de amigos dos usuários

# %%
count = 0

for x in users:
  count = count + len(x["friends"])
  #print(count)

media = count / len(users)
print(media)
# Out:
# 2.4

# %% [markdown]
# Mostrando o número de amigos de cada usuário

# %%
for user in users:
  print('{} tem {} amigos'.format(user['name'], len(user['friends'])))
# Out:
# Hero tem 2 amigos
# Dunn tem 3 amigos
# Sue tem 3 amigos
# Chi tem 3 amigos
# Thor tem 2 amigos
# Clive tem 3 amigos
# Hicks tem 2 amigos
# Devin tem 2 amigos
# Kate tem 3 amigos
# Klein tem 1 amigos

# %% [markdown]
# Mostrando quais são os usuários que tem mais amigos

# %%
max_friends = max([len(user['friends']) for user in users])
for user in users:
  if max_friends == len(user['friends']):
    print(user['name'])
# Out:
# Dunn
# Sue
# Chi
# Clive
# Kate

# %% [markdown]
# Mostrando quais usuários tem menos amigos

# %%
min_friends = min([len(user['friends']) for user in users])
for user in users:
  if min_friends == len(user['friends']):
    print(user['name'])
# Out:
# Klein

# %% [markdown]
# Mostrando quem são os amigos dos usuários mais populares

# %%
max_friends = max([len(user['friends']) for user in users])
for user in users:
  if max_friends == len(user['friends']):
    print('{} -> {}'.format(user['name'], [friend['name'] for friend in user['friends']]))
# Out:
# Dunn -> ['Hero', 'Sue', 'Chi']
# Sue -> ['Hero', 'Dunn', 'Chi']
# Chi -> ['Dunn', 'Sue', 'Thor']
# Clive -> ['Thor', 'Hicks', 'Devin']
# Kate -> ['Hicks', 'Devin', 'Klein']

# %% [markdown]
# Criando uma lista de tuplas com o id do usuário e a quantidade de amigos que ele tem

# %%
lista = []

for user in users:
  lista.append((user['id'], len(user['friends'])))

lista
# Out:
# [(0, 2),
#  (1, 3),
#  (2, 3),
#  (3, 3),
#  (4, 2),
#  (5, 3),
#  (6, 2),
#  (7, 2),
#  (8, 3),
#  (9, 1)]
