# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import csv

# %%
afrodev = open('/content/formulario_fofoqueiro.csv')

csvreader = csv.reader(afrodev, delimiter=';')

header = []
header = next(csvreader)

rows = []
for row in csvreader:
        rows.append(row)

# %%
{i: val for i, val in enumerate(header)}
# Out:
# {0: 'User_id',
#  1: 'Carimbo de data/hora',
#  2: 'Gênero ',
#  3: 'Idade',
#  4: 'CEP',
#  5: 'Gíria da sua cidade',
#  6: 'Estilo de música favorita',
#  7: 'Cor favorita ',
#  8: 'Número de irmãos ',
#  9: 'Qual seu salário dos sonhos ? ',
#  10: 'Gosta de programação',
#  11: 'Gosta de matemática',
#  12: 'Qual sua série favorita?',
#  13: 'Você gosta do seu nome?',
#  14: 'Você acredita em ET?',
#  15: 'Uma data importante',
#  16: 'Qual joia do infinito dos vingadores vocês gostaria de possuir ?',
#  17: 'O quão atraente você se considera de 0 até 10',
#  18: 'O quanto você gosta de café?',
#  19: 'Você prefere gato ou cachorro?'}

# %%
alunos_afrodev = np.array(rows)
afrodev.close()

# %%
dataframe = pd.DataFrame(alunos_afrodev)

# %%
dataframe.head(40)
# Out:
#     0                    1          2   ...  17  18        19
# 0    1  04/10/2021 20:05:11  Masculino  ...   8  10  Cachorro
# 1    2  04/10/2021 20:05:15  Masculino  ...  10   5  Cachorro
# 2    3  04/10/2021 20:05:25   Feminino  ...   8  10      Gato
# 3    4  04/10/2021 20:05:32  Masculino  ...   6   3      Gato
# 4    5  04/10/2021 20:05:34  Masculino  ...   8   5  Cachorro
# 5    6  04/10/2021 20:05:35  Masculino  ...   8   5  Cachorro
# 6    7  04/10/2021 20:05:51  Masculino  ...   6   7  Cachorro
# 7    8  04/10/2021 20:05:55  Masculino  ...   8   9      Gato
# 8    9  04/10/2021 20:06:08   Feminino  ...   8  10      Gato
# 9   10  04/10/2021 20:06:48   Feminino  ...   9   9      Gato
# 10  11  04/10/2021 20:07:03  Masculino  ...   7   0  Cachorro
# 11  12  04/10/2021 20:07:04   Feminino  ...   8   0  Cachorro
# 12  13  04/10/2021 20:07:23  Masculino  ...   7  10      Gato
# 13  14  04/10/2021 20:07:43   Feminino  ...   7   9  Cachorro
# ...

# %%
dataframe[3]
# Out:
# 0          31
# 1          26
# 2          23
# 3          27
# 4          20
# 5          30
# 6          27
# 7          28
# 8          43
# 9          28
# 10         24
# 11         39
# 12         33
# 13         32
# 14         21
# 15         25
# 16         41
# 17    33 anos
# 18    35 anos
# 19         20
# 20         26
# 21         52
# 22         29
# 23         23
# 24         38
# 25         35
# 26         41
# 27         20
# 28         23
# 29         28
# 30         21
# 31         21
# Name: 3, dtype: object

# %%
dataframe.iloc[[28], [5,7]]
# Out:
#         5        7
# 28  Mermã  Amarelo

# %%
dataframe.iloc[[0,3,4], [2,3,4]]

# %%
dataframe.loc[['0','3','4'], ['Gênero','Idade','CEP']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-5258000cb321> in <module>()
# ----> 1 dataframe.loc[['0','3','4'], ['Gênero','Idade','CEP']]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1051         # ugly hack for GH #836
#    1052         if self._multi_take_opportunity(tup):
# -> 1053             return self._multi_take(tup)
#    1054
#    1055         return self._getitem_tuple_same_dim(tup)
#
# ...
